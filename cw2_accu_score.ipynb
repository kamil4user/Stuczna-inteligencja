# %%
import pandas
import matplotlib as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
heart = pandas.read_csv("heart.csv")
df_breastc = pandas.read_csv("data.csv")

# %%
for col in df_breastc.columns:
    if col in ["id", "diagnosis", "Unnamed: 32"]:
        continue
    plt.pyplot.figure()
    sns.boxplot(x='diagnosis', y=col, data=b_cancer)
    plt.pyplot.title(f'{col} vs diagnosis')
    plt.pyplot.show()
